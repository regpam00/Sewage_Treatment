# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("Physical Nutrients Microbes (Cleaned).xlsx")
#print(df.head(10))

# %%
df.loc[1,:]
# Out:
# Chlorophyll A Mean (ng/ml)                               2.346201
# Date                                          2010-08-24 00:00:00
# Dissolved Organic Carbon (C) Value (mg/L)                1.401618
# GPS Latitude                                         48°14’14.8”N
# GPS Longitude                                       122°40’46.4”W
# Site Name                                                      PC
# Site Number                                                     3
# Ammonium (NH4+) µM                                        2.46202
# Nitrite (NO2-) µM                                        0.588824
# Nitrate (NO3-) µM                                       25.460402
# Phosphate (PO43-) µM                                     3.682698
# Silicate (Orthosilicic Acid) Si(OH)4 µM                 81.489478
# Depth of Grab (feet)                                           46
# Dissolved Oxygen (mg/L)                                      3.84
# ...

# %% [markdown]
# ### Penn Cove

# %%
# Selecting PC samples

penn_cove = df.loc[df['Site Name'] == 'PC']
print(penn_cove.head(5))
# Out:
#     Chlorophyll A Mean (ng/ml)       Date  \
# 0                     5.870782 2010-08-24
# 1                     2.346201 2010-08-24
# 2                     2.024505 2010-08-24
# 3                     1.282593 2010-08-24
# 16                    6.968570 2010-08-25
#
#     Dissolved Organic Carbon (C) Value (mg/L)     GPS Latitude  \
# 0                                    3.975442  48°4’13.99920”N
# 1                                    1.401618     48°14’14.8”N
# 2                                    1.149360     48°14’13.7”N
# 3                                    1.101972   48°14’04.566”N
# 16                                   2.085536     48°14’14.0”N
#
#         GPS Longitude Site Name  Site Number  Ammonium (NH4+) µM  \
# 0   122°40’43.97556”W        PC            1            1.480315
# 1       122°40’46.4”W        PC            3            2.462020
# 2       122°40’42.5”W        PC            2            2.390720
# ...

# %% [markdown]
# Nutrients

# %%
# Mean values of nutrients

nutrients_mean_cove = penn_cove.groupby(["Date"]).mean(numeric_only = True)
print(nutrients_mean_cove.loc[:,["Ammonium (NH4+) µM", "Nitrite (NO2-) µM", "Nitrate (NO3-) µM", "Phosphate (PO43-) µM", 
"Silicate (Orthosilicic Acid) Si(OH)4 µM"]])
# Out:
#             Ammonium (NH4+) µM  Nitrite (NO2-) µM  Nitrate (NO3-) µM  \
# Date
# 2010-08-24            2.247401           0.460007          19.481870
# 2010-08-25            3.126765           0.530456          19.187637
# 2010-08-26            1.876251           0.557067          22.124429
# 2010-11-21            2.127992           0.453048          26.186271
# 2010-11-23            1.124381           0.476229          26.815771
# 2011-02-15            0.721257           0.277780          27.058438
# 2011-02-16            1.086432           0.262376          26.127426
# 2011-02-17            0.641878           0.268270          27.776342
# 2011-05-17            0.365403           0.042992           1.701875
# 2011-05-18            3.317666           0.174296          17.905713
# 2011-05-19            2.948608           0.165982          18.073909
#
#             Phosphate (PO43-) µM  Silicate (Orthosilicic Acid) Si(OH)4 µM
# Date
# ...

# %%
# Standard deviations of nutrients

nutrients_std_cove = penn_cove.groupby(["Date"]).std(numeric_only = True)
print(nutrients_std_cove.loc[:,["Ammonium (NH4+) µM", "Nitrite (NO2-) µM", "Nitrate (NO3-) µM", "Phosphate (PO43-) µM", 
"Silicate (Orthosilicic Acid) Si(OH)4 µM"]])
# Out:
#             Ammonium (NH4+) µM  Nitrite (NO2-) µM  Nitrate (NO3-) µM  \
# Date
# 2010-08-24            0.523586           0.247837          12.666318
# 2010-08-25            2.285848           0.335974          12.542601
# 2010-08-26            0.327344           0.150091           9.379144
# 2010-11-21            0.779415           0.063942           3.998172
# 2010-11-23            0.787638           0.040891           4.029831
# 2011-02-15            0.112481           0.017563           2.398005
# 2011-02-16            0.705263           0.016997           2.812045
# 2011-02-17            0.400595           0.019038           2.789491
# 2011-05-17                 NaN                NaN                NaN
# 2011-05-18            2.021095           0.097417          11.915225
# 2011-05-19            1.896816           0.094487          11.945928
#
#             Phosphate (PO43-) µM  Silicate (Orthosilicic Acid) Si(OH)4 µM
# Date
# ...

# %%
# Variance of nutrients

nutrients_var_cove = penn_cove.groupby(["Date"]).var(numeric_only = True)
print(nutrients_var_cove.loc[:,["Ammonium (NH4+) µM", "Nitrite (NO2-) µM", "Nitrate (NO3-) µM", "Phosphate (PO43-) µM", 
"Silicate (Orthosilicic Acid) Si(OH)4 µM"]])
# Out:
#             Ammonium (NH4+) µM  Nitrite (NO2-) µM  Nitrate (NO3-) µM  \
# Date
# 2010-08-24            0.274142           0.061423         160.435615
# 2010-08-25            5.225099           0.112879         157.316839
# 2010-08-26            0.107154           0.022527          87.968347
# 2010-11-21            0.607488           0.004089          15.985379
# 2010-11-23            0.620373           0.001672          16.239540
# 2011-02-15            0.012652           0.000308           5.750427
# 2011-02-16            0.497396           0.000289           7.907596
# 2011-02-17            0.160476           0.000362           7.781262
# 2011-05-17                 NaN                NaN                NaN
# 2011-05-18            4.084825           0.009490         141.972584
# 2011-05-19            3.597910           0.008928         142.705208
#
#             Phosphate (PO43-) µM  Silicate (Orthosilicic Acid) Si(OH)4 µM
# Date
# ...

# %% [markdown]
# Microbial Cell Counts

# %%
# Mean values of microbial cells

microbes_mean_cove = penn_cove.groupby(["Date"]).mean(numeric_only = True)
print(microbes_mean_cove.loc[:,["Nanophytoplankton (cells/ml)", "FACS Eukaryotic Phytoplankton (cells/ml)", 
"FACS High Nucleic Acid Bacteria (cells/ml)", "FACS Low Nucleic Acid Bacteria (cells/ml)", "FACS Synechococcus (cells/ml)", "FACS Total Bacteria (cells/ml)"]])
# Out:
#             Nanophytoplankton (cells/ml)  \
# Date
# 2010-08-24                   2580.411011
# 2010-08-25                   4235.298096
# 2010-08-26                   1779.095335
# 2010-11-21                    945.126332
# 2010-11-23                    690.855567
# 2011-02-15                   1977.717101
# 2011-02-16                   2248.904761
# 2011-02-17                   1480.883971
# 2011-05-17                   2143.211809
# 2011-05-18                    936.318102
# 2011-05-19                    740.586556
#
#             FACS Eukaryotic Phytoplankton (cells/ml)  \
# Date
# 2010-08-24                               1711.902238
# 2010-08-25                               1934.487925
# 2010-08-26                               1146.475331
# 2010-11-21                               2557.126490
# 2010-11-23                               3245.321233
# 2011-02-15                              13141.143754
# 2011-02-16                              12271.529588
# ...

# %%
# Standard deviation values of microbial cells

microbes_std_cove = penn_cove.groupby(["Date"]).std(numeric_only = True)
print(microbes_std_cove.loc[:,["Nanophytoplankton (cells/ml)", "FACS Eukaryotic Phytoplankton (cells/ml)", 
"FACS High Nucleic Acid Bacteria (cells/ml)", "FACS Low Nucleic Acid Bacteria (cells/ml)", "FACS Synechococcus (cells/ml)", "FACS Total Bacteria (cells/ml)"]])
# Out:
#             Nanophytoplankton (cells/ml)  \
# Date
# 2010-08-24                   4369.012794
# 2010-08-25                   7259.867818
# 2010-08-26                   2531.072348
# 2010-11-21                   1162.593442
# 2010-11-23                    858.668224
# 2011-02-15                   1745.881347
# 2011-02-16                   1678.380603
# 2011-02-17                   2119.705901
# 2011-05-17                           NaN
# 2011-05-18                    829.193340
# 2011-05-19                    973.352646
#
#             FACS Eukaryotic Phytoplankton (cells/ml)  \
# Date
# 2010-08-24                               2215.952293
# 2010-08-25                               2543.595761
# 2010-08-26                               1024.450264
# 2010-11-21                               3737.022102
# 2010-11-23                               4656.201704
# 2011-02-15                              13094.639435
# 2011-02-16                               9074.128298
# ...

# %%
# Variance values of microbial cells

microbes_var_cove = penn_cove.groupby(["Date"]).var(numeric_only = True)
print(microbes_var_cove.loc[:,["Nanophytoplankton (cells/ml)", "FACS Eukaryotic Phytoplankton (cells/ml)", 
"FACS High Nucleic Acid Bacteria (cells/ml)", "FACS Low Nucleic Acid Bacteria (cells/ml)", "FACS Synechococcus (cells/ml)", "FACS Total Bacteria (cells/ml)"]])
# Out:
#             Nanophytoplankton (cells/ml)  \
# Date
# 2010-08-24                  1.908827e+07
# 2010-08-25                  5.270568e+07
# 2010-08-26                  6.406327e+06
# 2010-11-21                  1.351624e+06
# 2010-11-23                  7.373111e+05
# 2011-02-15                  3.048102e+06
# 2011-02-16                  2.816961e+06
# 2011-02-17                  4.493153e+06
# 2011-05-17                           NaN
# 2011-05-18                  6.875616e+05
# 2011-05-19                  9.474154e+05
#
#             FACS Eukaryotic Phytoplankton (cells/ml)  \
# Date
# 2010-08-24                              4.910445e+06
# 2010-08-25                              6.469879e+06
# 2010-08-26                              1.049498e+06
# 2010-11-21                              1.396533e+07
# 2010-11-23                              2.168021e+07
# 2011-02-15                              1.714696e+08
# 2011-02-16                              8.233980e+07
# ...

# %% [markdown]
# Graphs

# %%
old_dates = [date for date, df in df.groupby("Date")]
new_dates = list(pd.to_datetime(old_dates).strftime('%m/%d/%Y'))
print(new_dates)
# Out:
# ['08/24/2010', '08/25/2010', '08/26/2010', '11/21/2010', '11/23/2010', '02/15/2011', '02/16/2011', '02/17/2011', '05/17/2011', '05/18/2011', '05/19/2011']

# %%
microbes =['Nano PP','Eukaryotic PP', 'HNA Bacteria', 'LNA Bacteria', 'Synechococcus', 'Total Bacteria']
depth = [depth for depth, df in df.groupby("Depth of Grab (feet)")]
site_number = [site for site, df in df.groupby("Site Number")]
sites = [site for site, df in df.groupby("Site Name")]

# %%
# Mean values of nutrients

nutrients_mean_cove = penn_cove.groupby(["Date"]).mean(numeric_only = True)
dates = ['08/24/2010', '08/25/2010', '08/26/2010', '11/21/2010', '11/23/2010', '02/15/2011', '02/16/2011', '02/17/2011', '05/17/2011', '05/18/2011', '05/19/2011']

nutrients_mean_cove_1 = pd.DataFrame({
    "Dates" : dates,
    "Ammonium (NH4+)" : list(nutrients_mean_cove.loc[:,"Ammonium (NH4+) µM"]),
    "Nitrite (NO2-)" : list(nutrients_mean_cove.loc[:,"Nitrite (NO2-) µM"]),
    "Nitrate (NO3-)" : list(nutrients_mean_cove.loc[:,"Nitrate (NO3-) µM"]),
    "Phosphate (PO43-)" : list(nutrients_mean_cove.loc[:,"Phosphate (PO43-) µM"]),
    "Silicate (Si(OH)4)" : list(nutrients_mean_cove.loc[:,"Silicate (Orthosilicic Acid) Si(OH)4 µM"])
})
nutrients_mean_cove_2 = pd.melt(nutrients_mean_cove_1, id_vars = "Dates", var_name = "Nutrients", value_name = "Concentration (micromoles per liter)")
c = sns.catplot(data = nutrients_mean_cove_2, x = "Dates", y = "Concentration (micromoles per liter)", hue = "Nutrients", kind = "bar")
c.set_xticklabels(rotation = 90)
plt.title("Average Nutrient Concentrations Collected Per Sample Day in Penn Cove", loc = "center")
# Out:
# c:\Users\Regine Pamphile\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# Text(0.5, 1.0, 'Average Nutrient Concentrations Collected Per Sample Day in Penn Cove')

# %%
# Mean values of microbes

microbes_mean_cove = penn_cove.groupby(["Date"]).mean(numeric_only = True)
dates = ['08/24/2010', '08/25/2010', '08/26/2010', '11/21/2010', '11/23/2010', '02/15/2011', '02/16/2011', '02/17/2011', '05/17/2011', '05/18/2011', '05/19/2011']
microbes =['Nano PP','Eukaryotic PP', 'HNA Bacteria', 'LNA Bacteria', 'Synechococcus', 'Total Bacteria']

microbes_mean_cove_1 = pd.DataFrame({
    "Dates" : dates,
    "Nanophytoplankton" : list(microbes_mean_cove.loc[:,"Nanophytoplankton (cells/ml)"]),
    "Eukaryotic Phytoplankton" : list(microbes_mean_cove.loc[:,"FACS Eukaryotic Phytoplankton (cells/ml)"]),
    "HNA Bacteria" : list(microbes_mean_cove.loc[:,"FACS High Nucleic Acid Bacteria (cells/ml)"]),
    "LNA Bacteria" : list(microbes_mean_cove.loc[:,"FACS Low Nucleic Acid Bacteria (cells/ml)"]),
    "Synechococcus" : list(microbes_mean_cove.loc[:,"FACS Synechococcus (cells/ml)"]),
    "Total Bacteria" : list(microbes_mean_cove.loc[:,"FACS Total Bacteria (cells/ml)"])
})

microbes_mean_cove_2 = pd.melt(microbes_mean_cove_1, id_vars = "Dates", var_name = "Microbes", value_name = "Concentration (cells per microliter)")
c = sns.catplot(data = microbes_mean_cove_2, x = "Dates", y = "Concentration (cells per microliter)", hue = "Microbes", kind = "bar")
c.set_xticklabels(rotation = 90)
plt.title("Average Cell Concentrations Collected Per Sample Day in Penn Cove", loc = "center")
# Out:
# c:\Users\Regine Pamphile\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# Text(0.5, 1.0, 'Average Cell Concentrations Collected Per Sample Day in Penn Cove')

# %%
microbes_mean_cove = penn_cove.groupby(["Date"]).mean(numeric_only = True)
dates = ['08/24/2010', '08/25/2010', '08/26/2010', '11/21/2010', '11/23/2010', '02/15/2011', '02/16/2011', '02/17/2011', '05/17/2011', '05/18/2011', '05/19/2011']

microbes_mean_cove_1 = pd.DataFrame({
    "Dates" : dates,
    "Microbial Production (µg carbon/L /hour)" : list(microbes_mean_cove.loc[:,"Microbial Production (µg carbon/L /hour)"])
})

microbes_mean_cove_1.plot.line(x = "Dates", y = "Microbial Production (µg carbon/L /hour)", color = "#7995c4")
plt.title("Average Microbial Production at Penn Cove")
plt.legend(loc='upper center')
plt.ylabel("Microbial Production (µg carbon/L/hour)")
# Out:
# Text(0, 0.5, 'Microbial Production (µg carbon/L/hour)')

# %%
microbes_mean_cove = penn_cove.groupby(["Date"]).mean(numeric_only = True)
temps = nutrients_mean_cove.loc[:, "Water Temperature (°C)"]

microbes_mean_cove_1 = pd.DataFrame({
    "Temperature (Celsius)" : temps,
    "Microbial Production (µg carbon/L /hour)" : list(microbes_mean_cove.loc[:,"Microbial Production (µg carbon/L /hour)"])
})

microbes_mean_cove_1.plot.scatter(x = "Temperature (Celsius)", y = "Microbial Production (µg carbon/L /hour)", color = "#7995c4")
plt.title("Avg. Microbial Production at Penn Cove for Avg. Temperatures")
plt.legend()
plt.ylabel("Microbial Production (µg carbon/L/hour)")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Text(0, 0.5, 'Microbial Production (µg carbon/L/hour)')

# %%
microbes_mean_cove = penn_cove.groupby(["Date"]).mean(numeric_only = True)
salinity = nutrients_mean_cove.loc[:, "Salinity (ppt)"]

microbes_mean_cove_1 = pd.DataFrame({
    "Salinity (ppt)" : salinity,
    "Microbial Production (µg carbon/L /hour)" : list(microbes_mean_cove.loc[:,"Microbial Production (µg carbon/L /hour)"])
})

microbes_mean_cove_1.plot.scatter(x = "Salinity (ppt)", y = "Microbial Production (µg carbon/L /hour)", color = "#7995c4")
plt.title("Avg. Microbial Production at Penn Cove for Avg. Salinities")
plt.legend()
plt.ylabel("Microbial Production (µg carbon/L/hour)")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Text(0, 0.5, 'Microbial Production (µg carbon/L/hour)')

# %%
microbes_mean_cove = penn_cove.groupby(["Date"]).mean(numeric_only = True)
dissolved_oxy = nutrients_mean_cove.loc[:, "Dissolved Oxygen (mg/L)"]

microbes_mean_cove_1 = pd.DataFrame({
    "Dissolved Oxygen (mg/L)" : dissolved_oxy,
    "Microbial Production (µg carbon/L /hour)" : list(microbes_mean_cove.loc[:,"Microbial Production (µg carbon/L /hour)"])
})

microbes_mean_cove_1.plot.scatter(x = "Dissolved Oxygen (mg/L)", y = "Microbial Production (µg carbon/L /hour)", color = "#7995c4")
plt.title("Avg. Microbial Production at Penn Cove for Avg. Dissolved O2 Conc.")
plt.legend()
plt.ylabel("Microbial Production (µg carbon/L/hour)")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Text(0, 0.5, 'Microbial Production (µg carbon/L/hour)')

# %%
microbes_mean_cove = penn_cove.groupby(["Date"]).mean(numeric_only = True)
depths = nutrients_mean_cove.loc[:, "Depth of Grab (feet)"]

microbes_mean_cove_1 = pd.DataFrame({
    "Depth of Grab (feet)" : depths,
    "Microbial Production (µg carbon/L /hour)" : list(microbes_mean_cove.loc[:,"Microbial Production (µg carbon/L /hour)"])
})

microbes_mean_cove_1.plot.scatter(x = "Depth of Grab (feet)", y = "Microbial Production (µg carbon/L /hour)", color = "#7995c4")
plt.title("Avg. Microbial Production at Penn Cove for Avg. Depths")
plt.legend()
plt.ylabel("Microbial Production (µg carbon/L/hour)")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Text(0, 0.5, 'Microbial Production (µg carbon/L/hour)')

# %% [markdown]
# DNA Fragments

# %%
dna_frag = pd.read_excel("DNA Fragments (Cleaned).xlsx")
dna_frag_PC = dna_frag.loc[dna_frag["Site Name"] == "PC"]
dna_frag_PC.head()
# Out:
#     Unique ID Site Name  Site Number  71  75  77  79  81  83  85  ...  1179  \
# 0          21        PC            1   0   1   0   0   0   0   0  ...     0
# 1          22        PC            3   0   1   0   0   0   0   0  ...     0
# 2          23        PC            2   0   1   0   0   0   0   0  ...     0
# 3          24        PC            4   0   1   0   0   0   0   0  ...     0
# 16         37        PC            1   0   1   0   0   0   0   0  ...     0
#
#     1181  1183  1185  1187  1190  1194  1196  1199  Total Fragments
# 0      0     0     1     0     0     0     0     1              203
# 1      0     0     1     0     0     1     0     0              106
# 2      0     0     1     0     0     1     0     0              204
# 3      0     0     1     0     0     1     0     0              177
# 16     0     0     1     0     0     0     0     1              195
#
# [5 rows x 472 columns]

# %%
sns.set_theme(style="ticks")
f, ax = plt.subplots(figsize=(7, 5))
sns.despine(f)

sns.histplot(dna_frag_PC, x = "Total Fragments", color = "#7995c4")
plt.title("Distribution of DNA Fragments from Collected Samples (Penn Cove)")
# Out:
# Text(0.5, 1.0, 'Distribution of DNA Fragments from Collected Samples (Penn Cove)')

# %%
sns.displot(dna_frag_PC, x = "Total Fragments", kde="True")
plt.title("Distribution of DNA Fragments from Collected Samples (Penn Cove)")
# Out:
# c:\Users\Regine Pamphile\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# Text(0.5, 1.0, 'Distribution of DNA Fragments from Collected Samples (Penn Cove)')
