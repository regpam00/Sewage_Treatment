# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("Physical Nutrients Microbes (Cleaned).xlsx")
#print(df.head(10))

# %%
df.loc[1,:]
# Out:
# Chlorophyll A Mean (ng/ml)                               2.346201
# Date                                          2010-08-24 00:00:00
# Dissolved Organic Carbon (C) Value (mg/L)                1.401618
# GPS Latitude                                         48°14’14.8”N
# GPS Longitude                                       122°40’46.4”W
# Site Name                                                      PC
# Site Number                                                     3
# Ammonium (NH4+) µM                                        2.46202
# Nitrite (NO2-) µM                                        0.588824
# Nitrate (NO3-) µM                                       25.460402
# Phosphate (PO43-) µM                                     3.682698
# Silicate (Orthosilicic Acid) Si(OH)4 µM                 81.489478
# Depth of Grab (feet)                                           46
# Dissolved Oxygen (mg/L)                                      3.84
# ...

# %% [markdown]
# ### San de Fuca

# %%
# Selecting PC samples

san_de_fuca = df.loc[df['Site Name'] == 'SF']
print(san_de_fuca.head(5))
# Out:
#     Chlorophyll A Mean (ng/ml)       Date  \
# 8                    13.141112 2010-08-24
# 9                     6.566450 2010-08-24
# 14                    9.039488 2010-08-25
# 15                    8.496626 2010-08-25
# 24                   20.841710 2010-08-26
#
#     Dissolved Organic Carbon (C) Value (mg/L)   GPS Latitude   GPS Longitude  \
# 8                                    1.549428  48°13’43.27”N   122°43’38.13W
# 9                                    1.780271  48°13’43.27”N  122°43’38.13”W
# 14                                   1.594328  48°13’43.27”N  122°43’38.13”W
# 15                                   1.189983   48°13’43.3”N   122°43’38.1”W
# 24                                   1.569559   48°13’43.3”N   122°43’38.1”W
#
#    Site Name  Site Number  Ammonium (NH4+) µM  Nitrite (NO2-) µM  \
# 8         SF            1            0.404875           0.055017
# 9         SF            2            5.116299           0.811846
# ...

# %% [markdown]
# Nutrients

# %%
# Mean values of nutrients

nutrients_mean_sf = san_de_fuca.groupby(["Date"]).mean(numeric_only = True)
print(nutrients_mean_sf.loc[:,["Ammonium (NH4+) µM", "Nitrite (NO2-) µM", "Nitrate (NO3-) µM", "Phosphate (PO43-) µM", 
"Silicate (Orthosilicic Acid) Si(OH)4 µM"]])
# Out:
#             Ammonium (NH4+) µM  Nitrite (NO2-) µM  Nitrate (NO3-) µM  \
# Date
# 2010-08-24            2.760587           0.433431          11.348818
# 2010-08-25            2.502415           0.433521          10.927478
# 2010-08-26            3.024826           0.571869          16.499789
# 2010-11-21            3.849359           0.426220          21.350616
# 2010-11-23            2.134437           0.426215          20.904595
# 2011-02-15            0.718057           0.260443          24.683816
# 2011-02-16            0.658158           0.242331          24.867608
# 2011-02-17            0.516290           0.263253          25.712726
# 2011-05-17            0.123952           0.003584           0.017438
# 2011-05-18            0.363820           0.016183           0.179557
# 2011-05-19            0.102913           0.009030           0.133479
#
#             Phosphate (PO43-) µM  Silicate (Orthosilicic Acid) Si(OH)4 µM
# Date
# ...

# %%
# Standard deviations of nutrients

nutrients_std_sf = san_de_fuca.groupby(["Date"]).std(numeric_only = True)
print(nutrients_std_sf.loc[:,["Ammonium (NH4+) µM", "Nitrite (NO2-) µM", "Nitrate (NO3-) µM", "Phosphate (PO43-) µM", 
"Silicate (Orthosilicic Acid) Si(OH)4 µM"]])
# Out:
#             Ammonium (NH4+) µM  Nitrite (NO2-) µM  Nitrate (NO3-) µM  \
# Date
# 2010-08-24            3.331480           0.535159          15.556712
# 2010-08-25            3.045438           0.547557          14.825587
# 2010-08-26            1.835919           0.199231           6.328082
# 2010-11-21            2.396513           0.140066           2.330807
# 2010-11-23            0.087286           0.002266           0.182685
# 2011-02-15            0.258573           0.004836           1.172958
# 2011-02-16            0.258641           0.032445           1.855058
# 2011-02-17            0.141018           0.024785           2.949049
# 2011-05-17                 NaN                NaN                NaN
# 2011-05-18            0.185951           0.007625           0.046254
# 2011-05-19            0.113327           0.007660           0.028562
#
#             Phosphate (PO43-) µM  Silicate (Orthosilicic Acid) Si(OH)4 µM
# Date
# ...

# %%
# Variance of nutrients

nutrients_var_sf = san_de_fuca.groupby(["Date"]).var(numeric_only = True)
print(nutrients_var_sf.loc[:,["Ammonium (NH4+) µM", "Nitrite (NO2-) µM", "Nitrate (NO3-) µM", "Phosphate (PO43-) µM", 
"Silicate (Orthosilicic Acid) Si(OH)4 µM"]])
# Out:
#             Ammonium (NH4+) µM  Nitrite (NO2-) µM  Nitrate (NO3-) µM  \
# Date
# 2010-08-24           11.098757           0.286396         242.011276
# 2010-08-25            9.274694           0.299819         219.798032
# 2010-08-26            3.370598           0.039693          40.044624
# 2010-11-21            5.743277           0.019618           5.432662
# 2010-11-23            0.007619           0.000005           0.033374
# 2011-02-15            0.066860           0.000023           1.375831
# 2011-02-16            0.066895           0.001053           3.441238
# 2011-02-17            0.019886           0.000614           8.696890
# 2011-05-17                 NaN                NaN                NaN
# 2011-05-18            0.034578           0.000058           0.002139
# 2011-05-19            0.012843           0.000059           0.000816
#
#             Phosphate (PO43-) µM  Silicate (Orthosilicic Acid) Si(OH)4 µM
# Date
# ...

# %% [markdown]
# Microbial Cell Counts

# %%
# Mean values of microbial cells

microbes_mean_sf = san_de_fuca.groupby(["Date"]).mean(numeric_only = True)
print(microbes_mean_sf.loc[:,["Nanophytoplankton (cells/ml)", "FACS Eukaryotic Phytoplankton (cells/ml)", 
"FACS High Nucleic Acid Bacteria (cells/ml)", "FACS Low Nucleic Acid Bacteria (cells/ml)", "FACS Synechococcus (cells/ml)", "FACS Total Bacteria (cells/ml)"]])
# Out:
#             Nanophytoplankton (cells/ml)  \
# Date
# 2010-08-24                   6194.332743
# 2010-08-25                   4874.513257
# 2010-08-26                   3793.610982
# 2010-11-21                   2081.962363
# 2010-11-23                   2131.005492
# 2011-02-15                   2954.656454
# 2011-02-16                   2922.402514
# 2011-02-17                   1767.299790
# 2011-05-17                   3039.024390
# 2011-05-18                   1393.081876
# 2011-05-19                   2143.255824
#
#             FACS Eukaryotic Phytoplankton (cells/ml)  \
# Date
# 2010-08-24                               2614.568778
# 2010-08-25                               2307.498361
# 2010-08-26                               1675.886227
# 2010-11-21                               5008.656703
# 2010-11-23                              10121.153611
# 2011-02-15                              18337.482180
# 2011-02-16                              15201.257422
# ...

# %%
# Standard deviation values of microbial cells

microbes_std_sf = san_de_fuca.groupby(["Date"]).std(numeric_only = True)
print(microbes_std_sf.loc[:,["Nanophytoplankton (cells/ml)", "FACS Eukaryotic Phytoplankton (cells/ml)", 
"FACS High Nucleic Acid Bacteria (cells/ml)", "FACS Low Nucleic Acid Bacteria (cells/ml)", "FACS Synechococcus (cells/ml)", "FACS Total Bacteria (cells/ml)"]])
# Out:
#             Nanophytoplankton (cells/ml)  \
# Date
# 2010-08-24                   7541.235416
# 2010-08-25                   4963.152157
# 2010-08-26                   1122.392657
# 2010-11-21                   1486.626590
# 2010-11-23                    385.142346
# 2011-02-15                    638.168344
# 2011-02-16                    632.285563
# 2011-02-17                   1484.908861
# 2011-05-17                           NaN
# 2011-05-18                    214.534235
# 2011-05-19                    676.226905
#
#             FACS Eukaryotic Phytoplankton (cells/ml)  \
# Date
# 2010-08-24                               2587.297198
# 2010-08-25                               1794.210428
# 2010-08-26                                700.472937
# 2010-11-21                               2756.694525
# 2010-11-23                                939.169388
# 2011-02-15                               5464.801227
# 2011-02-16                               4703.548232
# ...

# %%
# Variance values of microbial cells

microbes_var_sf = san_de_fuca.groupby(["Date"]).var(numeric_only = True)
print(microbes_var_sf.loc[:,["Nanophytoplankton (cells/ml)", "FACS Eukaryotic Phytoplankton (cells/ml)", 
"FACS High Nucleic Acid Bacteria (cells/ml)", "FACS Low Nucleic Acid Bacteria (cells/ml)", "FACS Synechococcus (cells/ml)", "FACS Total Bacteria (cells/ml)"]])
# Out:
#             Nanophytoplankton (cells/ml)  \
# Date
# 2010-08-24                  5.687023e+07
# 2010-08-25                  2.463288e+07
# 2010-08-26                  1.259765e+06
# 2010-11-21                  2.210059e+06
# 2010-11-23                  1.483346e+05
# 2011-02-15                  4.072588e+05
# 2011-02-16                  3.997850e+05
# 2011-02-17                  2.204954e+06
# 2011-05-17                           NaN
# 2011-05-18                  4.602494e+04
# 2011-05-19                  4.572828e+05
#
#             FACS Eukaryotic Phytoplankton (cells/ml)  \
# Date
# 2010-08-24                              6.694107e+06
# 2010-08-25                              3.219191e+06
# 2010-08-26                              4.906623e+05
# 2010-11-21                              7.599365e+06
# 2010-11-23                              8.820391e+05
# 2011-02-15                              2.986405e+07
# 2011-02-16                              2.212337e+07
# ...

# %% [markdown]
# Graphs

# %%
old_dates = [date for date, df in df.groupby("Date")]
new_dates = list(pd.to_datetime(old_dates).strftime('%m/%d/%Y'))
print(new_dates)
# Out:
# ['08/24/2010', '08/25/2010', '08/26/2010', '11/21/2010', '11/23/2010', '02/15/2011', '02/16/2011', '02/17/2011', '05/17/2011', '05/18/2011', '05/19/2011']

# %%
microbes =['Nano PP','Eukaryotic PP', 'HNA Bacteria', 'LNA Bacteria', 'Synechococcus', 'Total Bacteria']
depth = [depth for depth, df in df.groupby("Depth of Grab (feet)")]
site_number = [site for site, df in df.groupby("Site Number")]
sites = [site for site, df in df.groupby("Site Name")]

# %%
# Mean values of nutrients

nutrients_mean_sf = san_de_fuca.groupby(["Date"]).mean(numeric_only = True)
dates = ['08/24/2010', '08/25/2010', '08/26/2010', '11/21/2010', '11/23/2010', '02/15/2011', '02/16/2011', '02/17/2011', '05/17/2011', '05/18/2011', '05/19/2011']

nutrients_mean_sf_1 = pd.DataFrame({
    "Dates" : dates,
    "Ammonium (NH4+)" : list(nutrients_mean_sf.loc[:,"Ammonium (NH4+) µM"]),
    "Nitrite (NO2-)" : list(nutrients_mean_sf.loc[:,"Nitrite (NO2-) µM"]),
    "Nitrate (NO3-)" : list(nutrients_mean_sf.loc[:,"Nitrate (NO3-) µM"]),
    "Phosphate (PO43-)" : list(nutrients_mean_sf.loc[:,"Phosphate (PO43-) µM"]),
    "Silicate (Si(OH)4)" : list(nutrients_mean_sf.loc[:,"Silicate (Orthosilicic Acid) Si(OH)4 µM"])
})
nutrients_mean_sf_2 = pd.melt(nutrients_mean_sf_1, id_vars = "Dates", var_name = "Nutrients", value_name = "Concentration (micromoles per liter)")
c = sns.catplot(data = nutrients_mean_sf_2, x = "Dates", y = "Concentration (micromoles per liter)", hue = "Nutrients", kind = "bar")
c.set_xticklabels(rotation = 90)
plt.title("Average Nutrient Concentrations Collected Per Sample Day in San de Fuca", loc = "center")
# Out:
# c:\Users\Regine Pamphile\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# Text(0.5, 1.0, 'Average Nutrient Concentrations Collected Per Sample Day in San de Fuca')

# %%
# Mean values of microbes

microbes_mean_sf = san_de_fuca.groupby(["Date"]).mean(numeric_only = True)
dates = ['08/24/2010', '08/25/2010', '08/26/2010', '11/21/2010', '11/23/2010', '02/15/2011', '02/16/2011', '02/17/2011', '05/17/2011', '05/18/2011', '05/19/2011']
microbes =['Nano PP','Eukaryotic PP', 'HNA Bacteria', 'LNA Bacteria', 'Synechococcus', 'Total Bacteria']

microbes_mean_sf_1 = pd.DataFrame({
    "Dates" : dates,
    "Nanophytoplankton" : list(microbes_mean_sf.loc[:,"Nanophytoplankton (cells/ml)"]),
    "Eukaryotic Phytoplankton" : list(microbes_mean_sf.loc[:,"FACS Eukaryotic Phytoplankton (cells/ml)"]),
    "HNA Bacteria" : list(microbes_mean_sf.loc[:,"FACS High Nucleic Acid Bacteria (cells/ml)"]),
    "LNA Bacteria" : list(microbes_mean_sf.loc[:,"FACS Low Nucleic Acid Bacteria (cells/ml)"]),
    "Synechococcus" : list(microbes_mean_sf.loc[:,"FACS Synechococcus (cells/ml)"]),
    "Total Bacteria" : list(microbes_mean_sf.loc[:,"FACS Total Bacteria (cells/ml)"])
})

microbes_mean_sf_2 = pd.melt(microbes_mean_sf_1, id_vars = "Dates", var_name = "Microbes", value_name = "Concentration (cells per microliter)")
c = sns.catplot(data = microbes_mean_sf_2, x = "Dates", y = "Concentration (cells per microliter)", hue = "Microbes", kind = "bar")
c.set_xticklabels(rotation = 90)
plt.title("Average Cell Concentrations Collected Per Sample Day in San de Fuca", loc = "center")
# Out:
# c:\Users\Regine Pamphile\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# Text(0.5, 1.0, 'Average Cell Concentrations Collected Per Sample Day in San de Fuca')

# %%
microbes_mean_sf = san_de_fuca.groupby(["Date"]).mean(numeric_only = True)
dates = ['08/24/2010', '08/25/2010', '08/26/2010', '11/21/2010', '11/23/2010', '02/15/2011', '02/16/2011', '02/17/2011', '05/17/2011', '05/18/2011', '05/19/2011']

microbes_mean_sf_1 = pd.DataFrame({
    "Dates" : dates,
    "Microbial Production (µg carbon/L /hour)" : list(microbes_mean_sf.loc[:,"Microbial Production (µg carbon/L /hour)"])
})

microbes_mean_sf_1.plot.line(x = "Dates", y = "Microbial Production (µg carbon/L /hour)", color = "#80be8e")
plt.title("Average Microbial Production at San de Fuca")
plt.legend(loc='upper center')
plt.ylabel("Microbial Production (µg carbon/L/hour)")
# Out:
# Text(0, 0.5, 'Microbial Production (µg carbon/L/hour)')

# %%
microbes_mean_sf = san_de_fuca.groupby(["Date"]).mean(numeric_only = True)
temps = nutrients_mean_sf.loc[:, "Water Temperature (°C)"]

microbes_mean_sf_1 = pd.DataFrame({
    "Temperature (Celsius)" : temps,
    "Microbial Production (µg carbon/L /hour)" : list(microbes_mean_sf.loc[:,"Microbial Production (µg carbon/L /hour)"])
})

microbes_mean_sf_1.plot.scatter(x = "Temperature (Celsius)", y = "Microbial Production (µg carbon/L /hour)", color = "#80be8e")
plt.title("Avg. Microbial Production at San de Fuca for Avg. Temperatures")
plt.legend()
plt.ylabel("Microbial Production (µg carbon/L/hour)")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Text(0, 0.5, 'Microbial Production (µg carbon/L/hour)')

# %%
microbes_mean_sf = san_de_fuca.groupby(["Date"]).mean(numeric_only = True)
salinity = nutrients_mean_sf.loc[:, "Salinity (ppt)"]

microbes_mean_sf_1 = pd.DataFrame({
    "Salinity (ppt)" : salinity,
    "Microbial Production (µg carbon/L /hour)" : list(microbes_mean_sf.loc[:,"Microbial Production (µg carbon/L /hour)"])
})

microbes_mean_sf_1.plot.scatter(x = "Salinity (ppt)", y = "Microbial Production (µg carbon/L /hour)", color = "#80be8e")
plt.title("Avg. Microbial Production at San de Fuca for Avg. Salinities")
plt.legend()
plt.ylabel("Microbial Production (µg carbon/L/hour)")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Text(0, 0.5, 'Microbial Production (µg carbon/L/hour)')

# %%
microbes_mean_sf = san_de_fuca.groupby(["Date"]).mean(numeric_only = True)
dissolved_oxy = nutrients_mean_sf.loc[:, "Dissolved Oxygen (mg/L)"]

microbes_mean_sf_1 = pd.DataFrame({
    "Dissolved Oxygen (mg/L)" : dissolved_oxy,
    "Microbial Production (µg carbon/L /hour)" : list(microbes_mean_sf.loc[:,"Microbial Production (µg carbon/L /hour)"])
})

microbes_mean_sf_1.plot.scatter(x = "Dissolved Oxygen (mg/L)", y = "Microbial Production (µg carbon/L /hour)", color = "#80be8e")
plt.title("Avg. Microbial Production at San de Fuca for Avg. Dissolved O2 Conc.")
plt.legend()
plt.ylabel("Microbial Production (µg carbon/L/hour)")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Text(0, 0.5, 'Microbial Production (µg carbon/L/hour)')

# %%
microbes_mean_sf = san_de_fuca.groupby(["Date"]).mean(numeric_only = True)
depths = nutrients_mean_sf.loc[:, "Depth of Grab (feet)"]

microbes_mean_cove_1 = pd.DataFrame({
    "Depth of Grab (feet)" : depths,
    "Microbial Production (µg carbon/L /hour)" : list(microbes_mean_sf.loc[:,"Microbial Production (µg carbon/L /hour)"])
})

microbes_mean_cove_1.plot.scatter(x = "Depth of Grab (feet)", y = "Microbial Production (µg carbon/L /hour)", color = "#80be8e")
plt.title("Avg. Microbial Production at San de Fuca for Avg. Depths")
plt.legend()
plt.ylabel("Microbial Production (µg carbon/L/hour)")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Text(0, 0.5, 'Microbial Production (µg carbon/L/hour)')

# %% [markdown]
# DNA Fragments

# %%
dna_frag = pd.read_excel("DNA Fragments (Cleaned).xlsx")
dna_frag_SF = dna_frag.loc[dna_frag["Site Name"] == "SF"]
dna_frag_SF.head()
# Out:
#     Unique ID Site Name  Site Number  71  75  77  79  81  83  85  ...  1179  \
# 8          29        SF            1   0   1   0   0   0   0   0  ...     0
# 9          30        SF            2   0   1   0   0   0   0   0  ...     0
# 14         35        SF            1   0   1   0   0   0   0   0  ...     0
# 15         36        SF            2   0   1   0   0   0   0   0  ...     0
# 24         45        SF            1   0   1   0   0   0   0   0  ...     0
#
#     1181  1183  1185  1187  1190  1194  1196  1199  Total Fragments
# 8      0     0     1     0     0     0     0     1              200
# 9      0     0     1     0     0     0     0     0              178
# 14     0     0     1     0     0     0     0     0              193
# 15     0     0     1     0     0     0     0     1              175
# 24     0     0     1     0     0     0     0     1              142
#
# [5 rows x 472 columns]

# %%
sns.set_theme(style="ticks")
f, ax = plt.subplots(figsize=(7, 5))
sns.despine(f)

sns.histplot(dna_frag_SF, x = "Total Fragments", color = "#80be8e")
plt.title("Distribution of DNA Fragments from Collected Samples (San de Fuca)")
# Out:
# Text(0.5, 1.0, 'Distribution of DNA Fragments from Collected Samples (San de Fuca)')

# %%
sns.displot(dna_frag_SF, x = "Total Fragments", color = "#80be8e", kde = "True")
plt.title("Distribution of DNA Fragments from Collected Samples (San de Fuca)")
# Out:
# c:\Users\Regine Pamphile\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# Text(0.5, 1.0, 'Distribution of DNA Fragments from Collected Samples (San de Fuca)')
